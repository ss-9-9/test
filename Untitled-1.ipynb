# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns 

from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df =pd.read_csv('C:/Users/DELL/Downloads/Extended_Employee_Performance_and_Productivity_Data.csv')

# %%
#for col in df.columns:print(col) , To show columns

df.dtypes
# Out:
# Employee_ID                      int64
# Department                      object
# Gender                          object
# Age                              int64
# Job_Title                       object
# Hire_Date                       object
# Years_At_Company                 int64
# Education_Level                 object
# Performance_Score                int64
# Monthly_Salary                 float64
# Work_Hours_Per_Week              int64
# Projects_Handled                 int64
# Overtime_Hours                   int64
# Sick_Days                        int64
# Remote_Work_Frequency            int64
# Team_Size                        int64
# Training_Hours                   int64
# Promotions                       int64
# Employee_Satisfaction_Score    float64
# Resigned                          bool
# dtype: object

# %%
corrmatrix= df.select_dtypes(include= ['float64','int64']).corr()

plt.figure(figsize= (12,6))
sns.heatmap(corrmatrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df.head()
# Out:
#    Employee_ID        Department  Gender  Age   Job_Title  \
# 0            1                IT    Male   55  Specialist
# 1            2           Finance    Male   29   Developer
# 2            3           Finance    Male   55  Specialist
# 3            4  Customer Support  Female   48     Analyst
# 4            5       Engineering  Female   36     Analyst
#
#                     Hire_Date  Years_At_Company Education_Level  \
# 0  2022-01-19 08:03:05.556036                 2     High School
# 1  2024-04-18 08:03:05.556036                 0     High School
# 2  2015-10-26 08:03:05.556036                 8     High School
# 3  2016-10-22 08:03:05.556036                 7        Bachelor
# 4  2021-07-23 08:03:05.556036                 3        Bachelor
#
#    Performance_Score  Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  \
# 0                  5          6750.0                   33                32
# ...

# %%
dfn = df.copy()

theorder = dfn['Education_Level'].unique()
theorder

dic = {'High School':0,'Bachelor':1,'Master':2,'PhD':3}
dfn['Education_Level'] = dfn['Education_Level'].map(dic)

dfn.head()
# Out:
#    Employee_ID        Department  Gender  Age   Job_Title  \
# 0            1                IT    Male   55  Specialist
# 1            2           Finance    Male   29   Developer
# 2            3           Finance    Male   55  Specialist
# 3            4  Customer Support  Female   48     Analyst
# 4            5       Engineering  Female   36     Analyst
#
#                     Hire_Date  Years_At_Company  Education_Level  \
# 0  2022-01-19 08:03:05.556036                 2                0
# 1  2024-04-18 08:03:05.556036                 0                0
# 2  2015-10-26 08:03:05.556036                 8                0
# 3  2016-10-22 08:03:05.556036                 7                1
# 4  2021-07-23 08:03:05.556036                 3                1
#
#    Performance_Score  Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  \
# 0                  5          6750.0                   33                32
# ...

# %%
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  int64
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Salary               100000 non-null  float64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
# ...

# %%
print (dfn['Department'].unique())


dfn = pd.get_dummies(dfn,columns= ['Department','Gender','Job_Title','Resigned'] , dtype=int)
dfn.head()
# Out:
# ['IT' 'Finance' 'Customer Support' 'Engineering' 'Marketing' 'HR'
#  'Operations' 'Sales' 'Legal']
#    Employee_ID  Age                   Hire_Date  Years_At_Company  \
# 0            1   55  2022-01-19 08:03:05.556036                 2
# 1            2   29  2024-04-18 08:03:05.556036                 0
# 2            3   55  2015-10-26 08:03:05.556036                 8
# 3            4   48  2016-10-22 08:03:05.556036                 7
# 4            5   36  2021-07-23 08:03:05.556036                 3
#
#    Education_Level  Performance_Score  Monthly_Salary  Work_Hours_Per_Week  \
# 0                0                  5          6750.0                   33
# 1                0                  5          7500.0                   34
# 2                0                  3          5850.0                   37
# 3                1                  2          4800.0                   52
# 4                1                  2          4800.0                   38
#
# ...

# %%
dfn=dfn.drop(columns= ['Employee_ID','Hire_Date'])
dfn.head()
# Out:
#    Age  Years_At_Company  Education_Level  Performance_Score  Monthly_Salary  \
# 0   55                 2                0                  5          6750.0
# 1   29                 0                0                  5          7500.0
# 2   55                 8                0                  3          5850.0
# 3   48                 7                1                  2          4800.0
# 4   36                 3                1                  2          4800.0
#
#    Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  Sick_Days  \
# 0                   33                32              22          2
# 1                   34                34              13         14
# 2                   37                27               6          3
# 3                   52                10              28         12
# 4                   38                11              29         13
#
#    Remote_Work_Frequency  ...  Gender_Other  Job_Title_Analyst  \
# ...

# %%
display(dfn.head())
# Out:
#    Age  Years_At_Company  Education_Level  Performance_Score  Monthly_Salary  \
# 0   55                 2                0                  5          6750.0
# 1   29                 0                0                  5          7500.0
# 2   55                 8                0                  3          5850.0
# 3   48                 7                1                  2          4800.0
# 4   36                 3                1                  2          4800.0
#
#    Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  Sick_Days  \
# 0                   33                32              22          2
# 1                   34                34              13         14
# 2                   37                27               6          3
# 3                   52                10              28         12
# 4                   38                11              29         13
#
#    Remote_Work_Frequency  ...  Gender_Other  Job_Title_Analyst  \
# ...

# %%
scaler = StandardScaler()
